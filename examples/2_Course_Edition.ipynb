# %% [markdown]
# # Install the package
#
# First, you need to install the package from github and import it:

# %%
# Install the bulkhours package
# !rm -rf bulkhours && git clone https://github.com/guydegnol/bulkhours.git

# import the bulkhours package
import bulkhours

# Generate header links
bulkhours.generate_header_links("examples/2_Course_Edition.ipynb")
# Out:
# Cloning into 'bulkhours'...
# remote: Enumerating objects: 5352, done.
# remote: Counting objects: 100% (951/951), done.
# remote: Compressing objects: 100% (328/328), done.
# remote: Total 5352 (delta 618), reused 900 (delta 588), pack-reused 4401
# Receiving objects: 100% (5352/5352), 40.97 MiB | 17.04 MiB/s, done.
# Resolving deltas: 100% (3455/3455), done.
# Import BULK Helper cOURSe (version='5.2.20'🚀', ⚠️ in admin/teacher🎓 mode⚠️):⚠️Database is local (security_level=0). Export your config file if you need persistency.⚠️
# (db, subject, virtual_room, nb_id, user) = (course2.json, '', winterfell, cadmin, the.lordoflight@got.grrm🎓)
# ...

# %% [markdown]
# # Initialization of the environnement
#
# Like in the previous tutorial, we should enter an email. On top of that, we will add several more info

# %%
bulkhours.init_env(
    email="the.lordoflight@got.grrm",  # Email of the teacher
    subject="bulkhours_sessions",      # Recommended to be unique for one entire subject
    notebook_id="course_edition_nb",   # Recommended to be unique per notebook (id of the current notenook)
    is_admin=True,                     # Switch to admin mode (Ok for the demo mode)
    database="data/cache/course2.json" # Database file
                   )

# %% [markdown]
# [Documentation for "`bulkhours.init_env`" is available here.](https://github.com/guydegnol/bulkhours/wiki/init_env)

# %% [markdown]
# ## Course parameters
#
# Now, you can edit the classroom information using the dashboard menu.

# %%
#@title # Configure course { run: "auto" }
#@markdown **Switch from one classroom to another:**
virtual_room = 'winterfell' #@param ["winterfell", "casterlyrock", "stormlands"] {allow-input: true}

bulkhours.admin.dashboard(virtual_room=virtual_room)
# Out:
# <style>
#     .widget-radio-box {
#         flex-direction: row !important;
#     }
#     .widget-radio-box label{
#         margin:5px !important;
#         width: 200px !important;
#     }
# </style>
# Box(children=(Box(children=(HTML(value="<b><font face='FiraCode Nerd Font' size=4 color='black'>winterfell<fon…
# Output()

# %%
#@title ## Suivre où en sont les élèves
bulkhours.admin.summary()
# Out:
# <style type="text/css">
# #T_64929_row0_col2, #T_64929_row1_col2, #T_64929_row4_col2, #T_64929_row5_col2, #T_64929_row6_col2, #T_64929_row7_col2 {
#   background-color: #67001f;
#   color: #f1f1f1;
#   background-color: #67001f;
#   color: #f1f1f1;
# }
# #T_64929_row0_col3, #T_64929_row1_col3, #T_64929_row4_col3, #T_64929_row5_col3, #T_64929_row6_col3, #T_64929_row7_col3 {
#   background-color: #000000;
#   color: #f1f1f1;
#   color: #FF3B52;
#   background-color: #FF3B52;
#   opacity: 20%;
#   opacity: 70%;
# }
# #T_64929_row2_col2, #T_64929_row3_col2 {
#   background-color: #053061;
#   color: #f1f1f1;
#   background-color: #053061;
#   color: #f1f1f1;
# }
# #T_64929_row2_col3, #T_64929_row3_col3 {
#   background-color: #053061;
#   color: #f1f1f1;
#   opacity: 70%;
# }
# </style>
# <table id="T_64929" class="dataframe">
#   <thead>
#     <tr>
#       <th id="T_64929_level0_col0" class="col_heading level0 col0" >nom</th>
# ...
