# %% [markdown]
# # Initialization of the environnement
#
# First, you need to install the package from github and import it.
# Like in the previous tutorial, we should enter an email.

# %%
# Install the bulkhours package, redirecting stdout and stderr to a null output
# !rm -rf bulkhours && git clone https://github.com/guydegnol/bulkhours.git > /dev/null 2>&1

# Import the bulkhours package
import bulkhours

# Like in the previous tutorial, we should enter an email. On top of that, we will add several more info
bulkhours.init_env(
    email="yoda@jedi.com",  # Email of the teacher
    subject="s",                       # Recommended to be unique for one entire subject
    notebook_id="course_edition_nb",   # Recommended to be unique per notebook (id of the current notenook)
    is_admin=True,                     # Switch to admin mode (Ok for the demo mode)
    database="data/cache/course2.json" # Database file
    )

# Generate header links
bulkhours.generate_header_links("examples/2_Course_Edition.ipynb")
# Out:
# Import BULK Helper cOURSe (version='5.2.24'🚀', ⚠️ in admin/teacher🎓 mode⚠️):
# (db, subject, virtual_room, nb_id, user) = (bkloud@, s, winterfell, course_edition_nb, the.lordoflight@got.grrm🎓)
# LOG import of openai failed 💥
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/guydegnol/bulkhours/blob/main/examples/2_Course_Edition.ipynb) [![Open In Kaggle](https://kaggle.com/static/images/open-in-kaggle.svg)](https://kaggle.com/kernels/welcome?src=https://github.com/guydegnol/bulkhours/blob/main/examples/2_Course_Edition.ipynb) [![GitHub](https://badgen.net/badge/icon/Open%20in%20Github?icon=github&label)](https://github.com/guydegnol/bulkhours/blob/main/examples/2_Course_Edition.ipynb) [![Open in Visual Studio Code](https://img.shields.io/static/v1?logo=visualstudiocode&label=&message=Open%20in%20Visual%20Studio&labelColor=2c2c32&color=007acc&logoColor=007acc)](https://vscode.dev/github/guydegnol/bulkhours/blob/main/examples/2_Course_Edition.ipynb) [![CC-by-nc-sa license](https://badgen.net/badge/icon/CC%20by-nc-sa?label=Licence)](https://creativecommons.org/licenses/by-nc-sa/4.0)

# %% [markdown]
# > 💡Documentation for "`bulkhours.init_env`" is [available here](https://github.com/guydegnol/bulkhours/wiki/init_env).

# %% [markdown]
# # Course parameters
#
# Now, you can edit the classroom information using the `bulkhours.admin.dashboard` method.

# %%
#@title ##### **Switch from one classroom to another:** { run: "auto" }
virtual_room = 'winterfell' #@param ["winterfell", "casterlyrock", "stormlands"] {allow-input: true}

bulkhours.admin.dashboard(virtual_room=virtual_room)
# Out:
# <style>
#     .widget-radio-box {
#         flex-direction: row !important;
#     }
#     .widget-radio-box label{
#         margin:5px !important;
#         width: 200px !important;
#     }
# </style>
# Box(children=(Box(children=(HTML(value="<b><font face='FiraCode Nerd Font' size=4 color='black'>winterfell<fon…
# Output()

# %% [markdown]
# You can switch from one classroom to another, using the virtual room button

# %%
#@title ## Suivre où en sont les élèves
bulkhours.admin.summary()
# Out:
# <style type="text/css">
# #T_80958_row0_col2, #T_80958_row1_col2, #T_80958_row2_col2, #T_80958_row3_col2, #T_80958_row4_col2 {
#   background-color: #67001f;
#   color: #f1f1f1;
#   background-color: #67001f;
#   color: #f1f1f1;
# }
# #T_80958_row0_col3, #T_80958_row1_col3, #T_80958_row2_col3, #T_80958_row3_col3, #T_80958_row4_col3 {
#   background-color: #000000;
#   color: #f1f1f1;
#   color: #FF3B52;
#   background-color: #FF3B52;
#   opacity: 20%;
#   opacity: 70%;
# }
# </style>
# <table id="T_80958" class="dataframe">
#   <thead>
#     <tr>
#       <th id="T_80958_level0_col0" class="col_heading level0 col0" >nom</th>
#       <th id="T_80958_level0_col1" class="col_heading level0 col1" >prenom</th>
#       <th id="T_80958_level0_col2" class="col_heading level0 col2" >all</th>
#       <th id="T_80958_level0_col3" class="col_heading level0 col3" ></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_80958_row0_col0" class="data row0 col0" >Kenobi</td>
#       <td id="T_80958_row0_col1" class="data row0 col1" >Obiwan</td>
#       <td id="T_80958_row0_col2" class="data row0 col2" >0.0</td>
#       <td id="T_80958_row0_col3" class="data row0 col3" >nan</td>
#     </tr>
#     <tr>
#       <td id="T_80958_row1_col0" class="data row1 col0" >Lordoflight</td>
#       <td id="T_80958_row1_col1" class="data row1 col1" >The</td>
#       <td id="T_80958_row1_col2" class="data row1 col2" >0.0</td>
#       <td id="T_80958_row1_col3" class="data row1 col3" >nan</td>
#     </tr>
#     <tr>
#       <td id="T_80958_row2_col0" class="data row2 col0" >Skywalker</td>
#       <td id="T_80958_row2_col1" class="data row2 col1" >Luke</td>
#       <td id="T_80958_row2_col2" class="data row2 col2" >0.0</td>
#       <td id="T_80958_row2_col3" class="data row2 col3" >nan</td>
#     </tr>
#     <tr>
#       <td id="T_80958_row3_col0" class="data row3 col0" >Ution</td>
#       <td id="T_80958_row3_col1" class="data row3 col1" >Sol</td>
#       <td id="T_80958_row3_col2" class="data row3 col2" >0.0</td>
#       <td id="T_80958_row3_col3" class="data row3 col3" >nan</td>
#     </tr>
#     <tr>
#       <td id="T_80958_row4_col0" class="data row4 col0" >None</td>
#       <td id="T_80958_row4_col1" class="data row4 col1" >Yoda</td>
#       <td id="T_80958_row4_col2" class="data row4 col2" >0.0</td>
#       <td id="T_80958_row4_col3" class="data row4 col3" >nan</td>
#     </tr>
#   </tbody>
# </table>

# %%
# %%evaluation_cell_id -i exo1
# print("exo1 solution")

# %%
# %%evaluation_cell_id -i exo2
# print("exo2 solution")
