# %% [markdown]
# # Install the package
#
# First, you need to install the package from github and import it:

# %%
# Install the bulkhours package
# !rm -rf bulkhours && git clone https://github.com/guydegnol/bulkhours.git

# import the bulkhours package
import bulkhours
bulkhours.init_env(email="dave.gahan@bulkhours.org", is_admin=True)

# Generate header links
bulkhours.generate_header_links("examples/2_Course_Edition.ipynb")
# Out:
# Cloning into 'bulkhours'...
# remote: Enumerating objects: 5182, done.
# remote: Counting objects: 100% (781/781), done.
# remote: Compressing objects: 100% (385/385), done.
# remote: Total 5182 (delta 490), reused 654 (delta 366), pack-reused 4401
# Receiving objects: 100% (5182/5182), 40.87 MiB | 23.34 MiB/s, done.
# Resolving deltas: 100% (3327/3327), done.
# Import BULK Helper cOURSe (version='5.2.16'🚀', ⚠️ in admin/teacher🎓 mode⚠️):⚠️Database is local (security_level=0). Export your config file if you need persistency.⚠️
# (db, subject, virtual_room, nb_id, user) = (free1.json, '', room1, '', dave.gahan@bulkhours.org🎓)
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/guydegnol/bulkhours/blob/main/examples/2_Course_Edition.ipynb) [![Open In Kaggle](https://kaggle.com/static/images/open-in-kaggle.svg)](https://kaggle.com/kernels/welcome?src=https://github.com/guydegnol/bulkhours/blob/main/examples/2_Course_Edition.ipynb) [![GitHub](https://badgen.net/badge/icon/Open%20in%20Github?icon=github&label)](https://github.com/guydegnol/bulkhours/blob/main/examples/2_Course_Edition.ipynb) [![Open in Visual Studio Code](https://img.shields.io/static/v1?logo=visualstudiocode&label=&message=Open%20in%20Visual%20Studio&labelColor=2c2c32&color=007acc&logoColor=007acc)](https://vscode.dev/github/guydegnol/bulkhours/blob/main/examples/2_Course_Edition.ipynb) [![CC-0 license](https://img.shields.io/badge/License-CC--0-blue.svg)](https://creativecommons.org/licenses/by-nd/4.0)

# %%
#@title ## Course parameters
bulkhours.admin.dashboard()
# Out:
# <style>
#     .widget-radio-box {
#         flex-direction: row !important;
#     }
#     .widget-radio-box label{
#         margin:5px !important;
#         width: 200px !important;
#     }
# </style>
# Box(children=(Box(children=(HTML(value="<b><font face='FiraCode Nerd Font' size=4 color='black'>room1<font></b…
# Output()

# %%
#@title ## Suivre où en sont les élèves
bulkhours.admin.summary()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-4-e721c83efca3> in <cell line: 2>()
#       1 #@title ## Suivre où en sont les élèves
# ----> 2 bulkhours.admin.summary()
#
# /content/bulkhours/bulkhours/admin/summary.py in summary(no_admin, reload_cache, cinfo, update_git, columns, cmap, **kwargs)
#      41         from .cache import cache_answers
#      42
# ---> 43         cache_answers(reload_cache if type(reload_cache) == list else exos, update_git=update_git, verbose=False)
#      44
#      45     data = tools.get_users_list(no_admin=no_admin)
#
# /content/bulkhours/bulkhours/admin/cache.py in cache_answers(cell_ids, update_git, verbose)
#       6 def cache_answers(cell_ids, update_git=False, verbose=True):
#       7     for cell_id in cell_ids:
# ----> 8         cache_answer(cell_id, update_git=False, verbose=verbose)
#       9
#      10     config = core.tools.get_config()
#
# /content/bulkhours/bulkhours/admin/cache.py in cache_answer(cell_id, **kwargs)
#      20
#      21 def cache_answer(cell_id, **kwargs):
# ---> 22     answers.get_answers(cell_id, **kwargs)
#
# /content/bulkhours/bulkhours/admin/answers.py in get_answers(cell_id, refresh, update_git, verbose)
#      22             cdata = json.load(json_file)
#      23
# ---> 24     docs = core.firebase.get_collection(cell_id, cinfo=cinfo).stream()
#      25
#      26     data = {}
#
# /content/bulkhours/bulkhours/core/firebase.py in stream(self)
#     107     def stream(self):
#     108         DbDocument.read_cache_data()
# --> 109         return [DbDocument(self.question, user) for user in DbDocument.data_base_cache[self.question]]
#     110
#     111
#
# KeyError: '_room1__'
