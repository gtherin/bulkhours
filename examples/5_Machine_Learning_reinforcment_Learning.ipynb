# %%
#@title # Initialisation { run: "auto" }
#@markdown **Enter the selected classroom:**

# Install the bulkhours package, redirecting stdout and stderr to a null output
# !rm -rf bulkhours && git clone https://github.com/guydegnol/bulkhours.git > /dev/null 2>&1

# import the bulkhours package
import bulkhours

# Jeton d'identification enseignant pour acceder à la base de donnée/code d'evaluation
database = "bkloud@prems/teacher::eNq-XXXXXXXXXXXXXXXXXXXXXXXXX-STS8XE"
print(f"""⚠️\x1b[41m\x1b[37mThis notebook was run with real-time db, openai and hugging-face tokens.
To reproduce results, you need your own tokens to run it! (contact bulkhours@guydegnol.net)\x1b[0m⚠️""")

bulkhours.init_env(email="yoda@jedi.com", notebook_id="ml", packages="openai", is_admin=True, database=database)#, packages="HUGGING_FACE"

# Classe virtuelle
virtual_room = 'light_side' #@param ["white_side", "dark_side"] {allow-input: true}

# Generate header links
bulkhours.generate_header_links("examples/5_Machine_Learning_reinforcment_Learning.ipynb")

# Import packages
import numpy as np
import pandas as pd
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.resnet50 import preprocess_input, decode_predictions

bulkhours.admin.dashboard(virtual_room=virtual_room)
# Out:
# ⚠️This notebook was run with real-time db, openai and hugging-face tokens.
# To reproduce results, you need your own tokens to run it! (contact bulkhours@guydegnol.net)⚠️
# RUN pip/apt install [colab]: openai [0s],
# Import BULK Helper cOURSe (version='5.2.25'🚀', ⚠️ in admin/teacher🎓 mode⚠️):
# (db, subject, virtual_room, nb_id, user) = (bkloud@, s, light_side, ml, yoda@jedi.com🎓)
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/guydegnol/bulkhours/blob/main/examples/5_Machine_Learning_reinforcment_Learning.ipynb) [![Open In Kaggle](https://kaggle.com/static/images/open-in-kaggle.svg)](https://kaggle.com/kernels/welcome?src=https://github.com/guydegnol/bulkhours/blob/main/examples/5_Machine_Learning_reinforcment_Learning.ipynb) [![GitHub](https://badgen.net/badge/icon/Open%20in%20Github?icon=github&label)](https://github.com/guydegnol/bulkhours/blob/main/examples/5_Machine_Learning_reinforcment_Learning.ipynb) [![Open in Visual Studio Code](https://img.shields.io/static/v1?logo=visualstudiocode&label=&message=Open%20in%20Visual%20Studio&labelColor=2c2c32&color=007acc&logoColor=007acc)](https://vscode.dev/github/guydegnol/bulkhours/blob/main/examples/5_Machine_Learning_reinforcment_Learning.ipynb) [![CC-by-nc-sa license](https://badgen.net/badge/icon/CC%20by-nc-sa?label=Licence)](https://creativecommons.org/licenses/by-nc-sa/4.0)
# <style>
#     .widget-radio-box {
#         flex-direction: row !important;
#     }
#     .widget-radio-box label{
#         margin:5px !important;
#         width: 200px !important;
#     }
# </style>
# Box(children=(Box(children=(HTML(value="<b><font face='FiraCode Nerd Font' size=4 color='black'>light_side<fon…
# Output()

# %%
#@title ## Students follow up
bulkhours.admin.summary()
# Out:
# <style type="text/css">
# #T_896aa_row0_col2, #T_896aa_row1_col2, #T_896aa_row3_col2 {
#   background-color: #67001f;
#   color: #f1f1f1;
#   background-color: #67001f;
#   color: #f1f1f1;
# }
# #T_896aa_row0_col3, #T_896aa_row0_col4, #T_896aa_row0_col5, #T_896aa_row1_col3, #T_896aa_row1_col4, #T_896aa_row1_col5, #T_896aa_row2_col5, #T_896aa_row3_col3, #T_896aa_row3_col4, #T_896aa_row3_col5 {
#   background-color: #000000;
#   color: #f1f1f1;
#   color: #FF3B52;
#   background-color: #FF3B52;
#   opacity: 20%;
#   opacity: 70%;
# }
# #T_896aa_row2_col2 {
#   background-color: #053061;
#   color: #f1f1f1;
#   background-color: #053061;
#   color: #f1f1f1;
# }
# #T_896aa_row2_col3, #T_896aa_row2_col4 {
#   background-color: #053061;
#   color: #f1f1f1;
#   opacity: 70%;
# }
# </style>
# <table id="T_896aa" class="dataframe">
#   <thead>
#     <tr>
#       <th id="T_896aa_level0_col0" class="col_heading level0 col0" >nom</th>
#       <th id="T_896aa_level0_col1" class="col_heading level0 col1" >prenom</th>
#       <th id="T_896aa_level0_col2" class="col_heading level0 col2" >all</th>
#       <th id="T_896aa_level0_col3" class="col_heading level0 col3" >cpp</th>
#       <th id="T_896aa_level0_col4" class="col_heading level0 col4" >aimg</th>
#       <th id="T_896aa_level0_col5" class="col_heading level0 col5" >moon</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_896aa_row0_col0" class="data row0 col0" >Kenobi</td>
#       <td id="T_896aa_row0_col1" class="data row0 col1" >Obiwan</td>
#       <td id="T_896aa_row0_col2" class="data row0 col2" >0.0</td>
#       <td id="T_896aa_row0_col3" class="data row0 col3" >nan</td>
#       <td id="T_896aa_row0_col4" class="data row0 col4" >nan</td>
#       <td id="T_896aa_row0_col5" class="data row0 col5" >nan</td>
#     </tr>
#     <tr>
#       <td id="T_896aa_row1_col0" class="data row1 col0" >Skywalker</td>
#       <td id="T_896aa_row1_col1" class="data row1 col1" >Luke</td>
#       <td id="T_896aa_row1_col2" class="data row1 col2" >0.0</td>
#       <td id="T_896aa_row1_col3" class="data row1 col3" >nan</td>
#       <td id="T_896aa_row1_col4" class="data row1 col4" >nan</td>
#       <td id="T_896aa_row1_col5" class="data row1 col5" >nan</td>
#     </tr>
#     <tr>
#       <td id="T_896aa_row2_col0" class="data row2 col0" >Ution</td>
#       <td id="T_896aa_row2_col1" class="data row2 col1" >Sol</td>
#       <td id="T_896aa_row2_col2" class="data row2 col2" >20.0</td>
#       <td id="T_896aa_row2_col3" class="data row2 col3" >10.0</td>
#       <td id="T_896aa_row2_col4" class="data row2 col4" >10.0</td>
#       <td id="T_896aa_row2_col5" class="data row2 col5" >nan</td>
#     </tr>
#     <tr>
#       <td id="T_896aa_row3_col0" class="data row3 col0" >None</td>
#       <td id="T_896aa_row3_col1" class="data row3 col1" >Yoda</td>
#       <td id="T_896aa_row3_col2" class="data row3 col2" >0.0</td>
#       <td id="T_896aa_row3_col3" class="data row3 col3" >nan</td>
#       <td id="T_896aa_row3_col4" class="data row3 col4" >nan</td>
#       <td id="T_896aa_row3_col5" class="data row3 col5" >nan</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# # Contruction of a geometric suite🔥
#
# Simple exercice are now directly solvable by chatgpt. Example:
# **Construire une suite géométrique de raison 2 en C++, de 2 à 1024:**

# %%
# %%evaluation_cell_id -i cpp -w scoag -l Construire une suite géométrique de raison 2 en C++, de 2 à 1024
# %%compile_and_exec -c g++
# #include <stdio.h>
#
# int main() {
#     int res = 1;
#     for (int i = 1; i <= 10; ++i)
#     {
#       res *= 2;
#       printf("%d ", res);
#     }
# }
#
# float student_evaluation_function(bool debug=false, bool run=false, bool show_code=false) {
#     return bulkhours.is_equal(student.stdout, teacher.stdout, policy="gaussian", error=0.1);
# }
# Out:
# HBox(children=(Button(button_style='primary', description='Envoyer au correcteur', layout=Layout(width='150px'…
# Output()

# %% [markdown]
# # Générer un énoncé d'exercice

# %%
bulkhours.ask_chat_gpt("Fabrique-moi un exercice de mécanique du point avec la fusée starship")
# Out:
# ### Fabrique-moi un exercice de mécanique du point avec la fusée starship
# Exercice :
#
# La fusée Starship, développée par SpaceX, est conçue pour transporter des charges utiles dans l'espace. Supposons que la fusée Starship se déplace horizontalement avec une vitesse initiale de 500 m/s et qu'elle subit une accélération constante de 10 m/s² pendant 10 secondes.
#
# 1) Calculez la vitesse finale de la fusée après 10 secondes.
#
# 2) Déterminez la distance parcourue par la fusée pendant ces 10 secondes.
#
# 3) Quelle est l'accélération moyenne de la fusée pendant cette période de 10 secondes ?
#
# 4) Supposons maintenant que la fusée soit soumise à une force de frottement due à l'atmosphère qui ralentit sa vitesse de 20 m/s². Calculez l'accélération nette de la fusée pendant ces 10 secondes.
#
# 5) En utilisant l'équation du mouvement, calculez le temps nécessaire pour que la fusée s'arrête complètement si elle continue de subir la même accélération nette.
#
# 6) Supposons que la fusée ait une masse de 100 000 kg. Calculez la force nette qui agit sur la fusée pendant ces 10 secondes.
#
# 7) Si la fusée devait transporter une charge utile de 10 000 kg, comment cela affecterait-il la force nette agissant sur la fusée ? Expliquez votre réponse.
#
# Note : Assurez-vous de prendre en compte les unités appropriées dans vos calculs et de montrer toutes les étapes de votre raisonnement.

# %% [markdown]
# # Evaluation du contenu d'une image avec du machine learning 🐍
#
# **Utiliser un réseau ResNet50 pour identifier le sujet principal d'une photo:**

# %%
# %%evaluation_cell_id -i aimg
#
# def get_predictions():
#
#     # Get and format image
#     img = image.load_img(bulkhours.get_data("chose1.jpg"), target_size=(224, 224))
#
#     # Display image
#     IPython.display.display(img)
#
#     # Format the image
#     rimg = np.expand_dims(image.img_to_array(img), axis=0)
#
#     # Use ResNet50 from tensorflow
#     model = bulkhours.hpc.get_tf_model("ResNet50");
#
#     # Get prediction
#     preds = model.predict(preprocess_input(rimg))
#
#     # Print classification
#     return pd.DataFrame(decode_predictions(preds, top=3)[0], columns=["idx", "Evaluation", "Probabilité"]).drop(columns=["idx"])
#
# get_predictions()
# Out:
# HBox(children=(Button(button_style='primary', description='Envoyer au correcteur', layout=Layout(width='150px'…
# Output()

# %% [markdown]
# # Atterissage d'un module lunaire🤖
#
# **Utiliser un algorithme RL (de type "Proximal Policy Optimization" preentrainé) pour faire atterir un module lunaire (Gymnasium):**

# %%
# %%evaluation_cell_id -i moon
# captain_robot = bulkhours.rl.PPOHugs(env_id="LunarLander-v2", init="bulkhours/ppo-LunarLander-v2")
# captain_robot.train(timesteps=1_000_000, push=True) # Train it for 1,000,000 timesteps
# captain_robot.visualize()
# Out:
# HBox(children=(Button(button_style='primary', description='Envoyer au correcteur', layout=Layout(width='150px'…
# Output()
